# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('final.csv')

# %%
df.head()
# Out:
#    PRECTOT  T2M_MIN  WS10M_MIN  W_Level  RES
# 0     0.00    12.23       1.38        0    0
# 1     0.00    12.97       0.89        0    0
# 2     0.68    15.97       0.28        0    0
# 3     0.00    11.76       3.26        0    0
# 4     0.00    11.27       1.88        0    0

# %%
sns.pairplot(data=df, hue='RES', palette='Set2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,4]
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[922   0   0   0   0   0]
#  [  9  24   0   0   0   0]
#  [  0   5  21   1   0   0]
#  [  0   0   0  13   0   0]
#  [  0   0   0   0  14   0]
#  [  0   0   0   0   1   4]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       922
#            1       0.83      0.73      0.77        33
#            2       1.00      0.78      0.88        27
#            3       0.93      1.00      0.96        13
#            4       0.93      1.00      0.97        14
#            5       1.00      0.80      0.89         5
#
#     accuracy                           0.98      1014
#    macro avg       0.95      0.88      0.91      1014
# weighted avg       0.98      0.98      0.98      1014
