# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('final.csv')

# %%
df.head()
# Out:
#    PRECTOT      PS  T2M_MIN  WS10M_MIN  RES
# 0     0.00  100.60    12.23       1.38    0
# 1     0.00  100.62    12.97       0.89    0
# 2     0.68  100.76    15.97       0.28    0
# 3     0.00  100.82    11.76       3.26    0
# 4     0.00  100.62    11.27       1.88    0

# %%
sns.pairplot(data=df, hue='RES', palette='Set2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,4]
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[924   0   0   0   0   0]
#  [ 29   0   0   0   0   0]
#  [ 27   0   0   0   0   0]
#  [  2  11   2   3   0   0]
#  [  0   0   0   0  11   0]
#  [  0   0   0   0   1   4]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       924
#            1       0.00      0.00      0.00        29
#            2       0.00      0.00      0.00        27
#            3       1.00      0.17      0.29        18
#            4       0.92      1.00      0.96        11
#            5       1.00      0.80      0.89         5
#
#     accuracy                           0.93      1014
#    macro avg       0.64      0.49      0.52      1014
# weighted avg       0.89      0.93      0.90      1014

# %%
df.describe()
# Out:
#           PRECTOT   T2M_RANGE      T2MDEW  WS10M_RANGE         RES
# count  147.000000  147.000000  147.000000   147.000000  147.000000
# mean    16.998639    7.005238   24.349864     3.244218    0.074830
# std     18.213964    2.119156    2.103065     1.325112    0.264016
# min      5.000000    3.170000    7.270000     0.750000    0.000000
# 25%      7.820000    5.505000   24.045000     2.255000    0.000000
# 50%     11.200000    6.890000   24.800000     3.040000    0.000000
# 75%     19.260000    8.155000   25.345000     4.005000    0.000000
# max    167.920000   13.360000   26.590000     7.760000    1.000000
